# %%
# !sudo apt-get install -qq -y libcairo2-dev libpango1.0-dev ffmpeg texlive texlive-latex-extra texlive-fonts-extra dvipng cm-super
# !pip install -q manim numpy scipy

# %%
import os, sys

REPO_URL    = 'https://github.com/Vtheonly/Manim_Video.git'
REPO_FOLDER = 'Manim_Video'

if os.path.exists(REPO_FOLDER):
    # !git -C {REPO_FOLDER} pull
else:
    # !git clone {REPO_URL}

os.chdir(REPO_FOLDER)
os.environ['PYTHONPATH'] = os.getcwd()
sys.path.insert(0, os.getcwd())

# %%
# !python render_all.py
